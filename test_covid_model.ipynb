# %% [markdown]
# # Covid Model
# ## Reading Data
# We are using the Kaggle dataset Covid 19 Radiography Dataset and we store the information read to avoid reading it again everytime.

# %%
import os
import cv2
import numpy as np
import tensorflow as tf

DIRECTORY = '/home/hivini/learn/research/new-covid/'
DATASET_FOLDER = DIRECTORY + 'COVID-19_Radiography_Dataset'
IMG_SIZE = 150

def readImages(files, name):
    if os.path.exists(name):
        return np.load(name, allow_pickle=True)
    data = []
    for path_im in files:
        try:
            img_arr = cv2.imread(path_im, cv2.IMREAD_GRAYSCALE)
            resized_arr = cv2.resize(img_arr, (IMG_SIZE, IMG_SIZE))
            data.append(resized_arr) # Reshaping images to preferred size
        except Exception as e:
            print(e)
    arr = np.array(data, dtype='object')
    np.save(name, arr)
    return arr


covid_filenames = tf.io.gfile.glob(DATASET_FOLDER + '/COVID/*')
normal_filenames = tf.io.gfile.glob(DATASET_FOLDER + '/Normal/*')
covid_images = readImages(covid_filenames, DIRECTORY + 'cxr_covid.npy')
normal_images = readImages(normal_filenames, DIRECTORY + 'cxr_normal.npy')
# Taking the easy way out.
# TODO(hivini): Is better to inflate the other Covid Dataset.
normal_images = normal_images[:covid_images.shape[0]]
print(covid_images.shape)
print(normal_images.shape)
# Out:
# 2021-09-23 22:19:12.284350: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# (3616, 150, 150)
# (3616, 150, 150)

# %%
import matplotlib.pyplot as plt
#Plotting Distribution of Each Classes
image_count = {'covid': covid_images.shape[0], 'normal': normal_images.shape[0]}
fig1, ax1 = plt.subplots()
ax1.pie(image_count.values(),
        labels = image_count.keys(),
        shadow=True,
        autopct = '%1.1f%%',
        startangle=90)
plt.show()

# %% [markdown]
# ## Separate the training and test data.

# %%
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

covid_labels = np.ones(covid_images.shape[0])
normal_labels = np.zeros(normal_images.shape[0])
all_images = np.concatenate((covid_images, normal_images))
all_labels = np.concatenate((covid_labels, normal_labels))
train_images, test_images, train_labels, test_labels = train_test_split(all_images, all_labels, test_size=0.20)
train_images = train_images.reshape((train_images.shape[0], IMG_SIZE, IMG_SIZE, 1))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((test_images.shape[0], IMG_SIZE, IMG_SIZE, 1))
test_images = test_images.astype('float32') / 255

print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)
# Out:
# (5785, 150, 150, 1)
# (5785,)
# (1447, 150, 150, 1)
# (1447,)

# %%
print(train_labels)
# Out:
# [1. 1. 0. ... 0. 0. 1.]

# %%
plt.clf()
plt.imshow(cv2.cvtColor(train_images[0], cv2.COLOR_GRAY2RGB))
plt.show()

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3,3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3,3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3,3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.summary()
# Out:
# 2021-09-23 22:19:34.317499: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-23 22:19:34.338827: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-09-23 22:19:34.940612: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2021-09-23 22:19:34.941066: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2080 with Max-Q Design computeCapability: 7.5
# coreClock: 1.215GHz coreCount: 46 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 357.69GiB/s
# 2021-09-23 22:19:34.941150: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-09-23 22:19:34.997784: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-09-23 22:19:34.997930: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-09-23 22:19:35.024870: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-23 22:19:35.031878: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-23 22:19:35.077827: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-23 22:19:35.084197: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-09-23 22:19:35.163568: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-09-23 22:19:35.164811: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2021-09-23 22:19:35.166278: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2021-09-23 22:19:35.166735: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-23 22:19:35.169398: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-09-23 22:19:35.172331: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2021-09-23 22:19:35.172864: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2080 with Max-Q Design computeCapability: 7.5
# coreClock: 1.215GHz coreCount: 46 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 357.69GiB/s
# 2021-09-23 22:19:35.172939: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-09-23 22:19:35.173012: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-09-23 22:19:35.173054: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-09-23 22:19:35.173118: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-23 22:19:35.173162: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-23 22:19:35.173199: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-23 22:19:35.173238: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-09-23 22:19:35.173275: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-09-23 22:19:35.174412: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2021-09-23 22:19:35.175965: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2021-09-23 22:19:35.176433: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-23 22:19:35.177258: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-09-23 22:19:37.035925: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-09-23 22:19:37.035959: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-09-23 22:19:37.035966: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-09-23 22:19:37.037881: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2021-09-23 22:19:37.038157: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1489] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2021-09-23 22:19:37.039234: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2021-09-23 22:19:37.040582: E tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:927] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2021-09-23 22:19:37.040923: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6575 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2080 with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5)
# 2021-09-23 22:19:37.043390: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 3,452,545
# Trainable params: 3,452,545
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import optimizers
model.compile(optimizer=optimizers.RMSprop(lr=1e-4), loss='binary_crossentropy', metrics=['accuracy'])

# %%
print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)
history = model.fit(train_images, train_labels, epochs=30, batch_size=100, validation_data=(test_images, test_labels))
model.save(DIRECTORY + 'covid_model_result.h5')
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# (5785, 150, 150, 1)
# (5785,)
# (1447, 150, 150, 1)
# (1447,)
# 2021-09-23 22:19:37.627641: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 520650000 exceeds 10% of free system memory.
# 2021-09-23 22:19:38.121804: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-09-23 22:19:38.127821: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2208005000 Hz
# Epoch 1/30
# 2021-09-23 22:19:39.659876: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-09-23 22:19:40.187262: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-09-23 22:19:45.163129: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2021-09-23 22:19:45.359317: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 58/58 [==============================] - ETA: 0s - loss: 0.6679 - accuracy: 0.6019
# 2021-09-23 22:20:56.577625: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 130230000 exceeds 10% of free system memory.
# 58/58 [==============================] - 95s 1s/step - loss: 0.6674 - accuracy: 0.6027 - val_loss: 0.5611 - val_accuracy: 0.7139
# Epoch 2/30
# 58/58 [==============================] - 4s 74ms/step - loss: 0.5552 - accuracy: 0.7179 - val_loss: 0.5248 - val_accuracy: 0.7270
# Epoch 3/30
# 58/58 [==============================] - 4s 71ms/step - loss: 0.4698 - accuracy: 0.7704 - val_loss: 0.4466 - val_accuracy: 0.7975
# Epoch 4/30
# 58/58 [==============================] - 4s 69ms/step - loss: 0.4159 - accuracy: 0.8105 - val_loss: 0.4203 - val_accuracy: 0.8003
# Epoch 5/30
# 58/58 [==============================] - 4s 65ms/step - loss: 0.3808 - accuracy: 0.8294 - val_loss: 0.4726 - val_accuracy: 0.7878
# Epoch 6/30
# 58/58 [==============================] - 4s 65ms/step - loss: 0.3504 - accuracy: 0.8463 - val_loss: 0.3450 - val_accuracy: 0.8556
# Epoch 7/30
# 58/58 [==============================] - 4s 66ms/step - loss: 0.3134 - accuracy: 0.8711 - val_loss: 0.3378 - val_accuracy: 0.8735
# Epoch 8/30
# 58/58 [==============================] - 4s 65ms/step - loss: 0.3101 - accuracy: 0.8710 - val_loss: 0.3075 - val_accuracy: 0.8804
# Epoch 9/30
# 58/58 [==============================] - 4s 66ms/step - loss: 0.2734 - accuracy: 0.8908 - val_loss: 0.3740 - val_accuracy: 0.8459
# Epoch 10/30
# 58/58 [==============================] - 4s 65ms/step - loss: 0.2740 - accuracy: 0.8867 - val_loss: 0.2819 - val_accuracy: 0.8818
# Epoch 11/30
# 58/58 [==============================] - 4s 65ms/step - loss: 0.2438 - accuracy: 0.9027 - val_loss: 0.4065 - val_accuracy: 0.8134
# Epoch 12/30
# 58/58 [==============================] - 4s 66ms/step - loss: 0.2664 - accuracy: 0.8852 - val_loss: 0.2917 - val_accuracy: 0.8763
# Epoch 13/30
# 58/58 [==============================] - 4s 66ms/step - loss: 0.2245 - accuracy: 0.9090 - val_loss: 0.2518 - val_accuracy: 0.8984
# Epoch 14/30
# 58/58 [==============================] - 4s 66ms/step - loss: 0.2030 - accuracy: 0.9196 - val_loss: 0.5416 - val_accuracy: 0.7851
# Epoch 15/30
# 58/58 [==============================] - 4s 66ms/step - loss: 0.2230 - accuracy: 0.9120 - val_loss: 0.2283 - val_accuracy: 0.9053
# Epoch 16/30
# 58/58 [==============================] - 4s 70ms/step - loss: 0.2010 - accuracy: 0.9177 - val_loss: 0.2176 - val_accuracy: 0.9109
# Epoch 17/30
# 58/58 [==============================] - 4s 70ms/step - loss: 0.1690 - accuracy: 0.9333 - val_loss: 0.2370 - val_accuracy: 0.9074
# Epoch 18/30
# 58/58 [==============================] - 4s 70ms/step - loss: 0.1853 - accuracy: 0.9251 - val_loss: 0.2079 - val_accuracy: 0.9122
# Epoch 19/30
# 58/58 [==============================] - 4s 70ms/step - loss: 0.1625 - accuracy: 0.9436 - val_loss: 0.2167 - val_accuracy: 0.9150
# Epoch 20/30
# 58/58 [==============================] - 4s 70ms/step - loss: 0.1482 - accuracy: 0.9437 - val_loss: 0.2250 - val_accuracy: 0.9115
# Epoch 21/30
# 58/58 [==============================] - 4s 71ms/step - loss: 0.1527 - accuracy: 0.9440 - val_loss: 0.2082 - val_accuracy: 0.9191
# Epoch 22/30
# 58/58 [==============================] - 4s 71ms/step - loss: 0.1307 - accuracy: 0.9509 - val_loss: 0.1869 - val_accuracy: 0.9240
# Epoch 23/30
# 58/58 [==============================] - 4s 70ms/step - loss: 0.1366 - accuracy: 0.9473 - val_loss: 0.2405 - val_accuracy: 0.9074
# Epoch 24/30
# 58/58 [==============================] - 4s 73ms/step - loss: 0.1389 - accuracy: 0.9416 - val_loss: 0.1993 - val_accuracy: 0.9198
# Epoch 25/30
# 58/58 [==============================] - 4s 72ms/step - loss: 0.1161 - accuracy: 0.9549 - val_loss: 0.2469 - val_accuracy: 0.8998
# Epoch 26/30
# 58/58 [==============================] - 4s 70ms/step - loss: 0.1137 - accuracy: 0.9580 - val_loss: 0.1767 - val_accuracy: 0.9288
# Epoch 27/30
# 58/58 [==============================] - 4s 70ms/step - loss: 0.1022 - accuracy: 0.9650 - val_loss: 0.1846 - val_accuracy: 0.9267
# Epoch 28/30
# 58/58 [==============================] - 4s 71ms/step - loss: 0.1001 - accuracy: 0.9638 - val_loss: 0.1729 - val_accuracy: 0.9343
# Epoch 29/30
# 58/58 [==============================] - 4s 70ms/step - loss: 0.0928 - accuracy: 0.9688 - val_loss: 0.1778 - val_accuracy: 0.9330
# Epoch 30/30
# 58/58 [==============================] - 4s 70ms/step - loss: 0.0914 - accuracy: 0.9643 - val_loss: 0.3128 - val_accuracy: 0.8749
# 2021-09-23 22:23:09.546228: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 130230000 exceeds 10% of free system memory.
# 46/46 [==============================] - 26s 292ms/step - loss: 0.3128 - accuracy: 0.8749

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)
# bo is for blue dot.
plt.plot(epochs, loss, 'bo', label='Training loss')
# b is for solid blue line
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
